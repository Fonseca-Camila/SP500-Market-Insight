# %%
import pandas as pd

# %%
df = pd.read_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sp500_companies2.csv')
df.head()
# Out:
#   Exchange Symbol              Shortname               Longname  \
# 0      NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation
# 1      NMS   AAPL             Apple Inc.             Apple Inc.
# 2      NMS   MSFT  Microsoft Corporation  Microsoft Corporation
# 3      NMS  GOOGL          Alphabet Inc.          Alphabet Inc.
# 4      NMS   GOOG          Alphabet Inc.          Alphabet Inc.
#
#                    Sector                        Industry  Currentprice  \
# 0              Technology                  Semiconductors        147.63
# 1              Technology            Consumer Electronics        226.96
# 2              Technology       Software - Infrastructure        422.54
# 3  Communication Services  Internet Content & Information        178.35
# 4  Communication Services  Internet Content & Information        179.86
#
#        Marketcap        Ebitda  Revenuegrowth           City State  \
# 0  3621363908608  6.118400e+10          1.224    Santa Clara    CA
# ...

# %%
df = df.drop(columns=['Longbusinesssummary'])
df.head()
# Out:
#   Exchange Symbol              Shortname               Longname  \
# 0      NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation
# 1      NMS   AAPL             Apple Inc.             Apple Inc.
# 2      NMS   MSFT  Microsoft Corporation  Microsoft Corporation
# 3      NMS  GOOGL          Alphabet Inc.          Alphabet Inc.
# 4      NMS   GOOG          Alphabet Inc.          Alphabet Inc.
#
#                    Sector                        Industry  Currentprice  \
# 0              Technology                  Semiconductors        147.63
# 1              Technology            Consumer Electronics        226.96
# 2              Technology       Software - Infrastructure        422.54
# 3  Communication Services  Internet Content & Information        178.35
# 4  Communication Services  Internet Content & Information        179.86
#
#        Marketcap        Ebitda  Revenuegrowth           City State  \
# 0  3621363908608  6.118400e+10          1.224    Santa Clara    CA
# ...

# %%
df.to_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sp500_companies4.csv', sep=';', index=False, quotechar='"', na_rep='NULL')

# %%
df4 = pd.read_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sp500_companies4.csv')

# %%
df_stocks = pd.read_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sp500_stocks.csv')
df_stocks.head()
# Out:
#          Date Symbol  Adj Close      Close       High        Low       Open  \
# 0  2010-01-04    MMM  44.016705  69.414719  69.774246  69.122070  69.473244
# 1  2010-01-05    MMM  43.741013  68.979935  69.590302  68.311035  69.230766
# 2  2010-01-06    MMM  44.361359  69.958191  70.735786  69.824417  70.133781
# 3  2010-01-07    MMM  44.393150  70.008362  70.033447  68.662209  69.665550
# 4  2010-01-08    MMM  44.705975  70.501671  70.501671  69.648827  69.974915
#
#       Volume
# 0  3640265.0
# 1  3405012.0
# 2  6301126.0
# 3  5346240.0
# 4  4073337.0

# %%
df_stocks = df_stocks[df_stocks['Symbol'] != 'ABBV']
df_stocks = df_stocks[df_stocks['Symbol'] != 'ABNB']

# %%
df_stocks.head()
# Out:
#          Date Symbol  Adj Close      Close       High        Low       Open  \
# 0  2010-01-04    MMM  44.016705  69.414719  69.774246  69.122070  69.473244
# 1  2010-01-05    MMM  43.741013  68.979935  69.590302  68.311035  69.230766
# 2  2010-01-06    MMM  44.361359  69.958191  70.735786  69.824417  70.133781
# 3  2010-01-07    MMM  44.393150  70.008362  70.033447  68.662209  69.665550
# 4  2010-01-08    MMM  44.705975  70.501671  70.501671  69.648827  69.974915
#
#       Volume
# 0  3640265.0
# 1  3405012.0
# 2  6301126.0
# 3  5346240.0
# 4  4073337.0

# %%
df_stocks.iloc[52346]
# Out:
# Date         2010-01-04
# Symbol             ALLE
# Adj Close           NaN
# Close               NaN
# High                NaN
# Low                 NaN
# Open                NaN
# Volume              NaN
# Name: 59824, dtype: object

# %%
df_stocks.isnull().sum()
# Out:
# Date             0
# Symbol           0
# Adj Close    98118
# Close        98118
# High         98118
# Low          98118
# Open         98118
# Volume       98118
# dtype: int64

# %%
df_stocks = df_stocks.dropna()

# %%
df_stocks.isnull().sum()
# Out:
# Date         0
# Symbol       0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64

# %%
df_stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1775121 entries, 0 to 1880716
# Data columns (total 8 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Date       object
#  1   Symbol     object
#  2   Adj Close  float64
#  3   Close      float64
#  4   High       float64
#  5   Low        float64
#  6   Open       float64
#  7   Volume     float64
# dtypes: float64(6), object(2)
# memory usage: 121.9+ MB

# %%
df_stocks.to_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sp500_stocks1.csv', index=False)

# %%
df_stocks.to_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sp500_stocks1.csv', sep=',', index=False, quotechar='"', na_rep='NULL')

# %%
df1 = pd.read_csv('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/sp500_stocks1.csv',sep=';')
df1.head()
# Out:
#          Date Symbol  Adj Close      Close       High        Low       Open  \
# 0  2010-01-04    MMM  44.016705  69.414719  69.774246  69.122070  69.473244
# 1  2010-01-05    MMM  43.741013  68.979935  69.590302  68.311035  69.230766
# 2  2010-01-06    MMM  44.361359  69.958191  70.735786  69.824417  70.133781
# 3  2010-01-07    MMM  44.393150  70.008362  70.033447  68.662209  69.665550
# 4  2010-01-08    MMM  44.705975  70.501671  70.501671  69.648827  69.974915
#
#       Volume
# 0  3640265.0
# 1  3405012.0
# 2  6301126.0
# 3  5346240.0
# 4  4073337.0

# %%
df1.tail()
# Out:
#                Date Symbol   Adj Close       Close        High         Low  \
# 1880712  2024-11-04    ZTS  175.179993  175.179993  179.169998  173.589996
# 1880713  2024-11-05    ZTS  175.270004  175.270004  176.800003  172.250000
# 1880714  2024-11-06    ZTS  170.369995  170.369995  178.919998  169.309998
# 1880715  2024-11-07    ZTS  174.250000  174.250000  174.789993  169.639999
# 1880716  2024-11-08    ZTS  176.820007  176.820007  177.100006  173.220001
#
#                Open     Volume
# 1880712  176.639999  4164000.0
# 1880713  174.559998  2453800.0
# 1880714  178.520004  5362100.0
# 1880715  172.589996  3781300.0
# 1880716  174.250000  3243400.0

# %%
df1.iloc[11217]
# Out:
# Date         2010-01-04
# Symbol             ABBV
# Adj Close           NaN
# Close               NaN
# High                NaN
# Low                 NaN
# Open                NaN
# Volume              NaN
# Name: 11217, dtype: object
